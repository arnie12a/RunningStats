# %%
import pandas as pd
df = pd.read_csv('runs.csv')
df
# Out:
#          Date  WeekNumber  DayOfWeek   WorkoutType  Distance      Time  \
# 0  2025-08-11           1     Monday      Easy Run      1.50  00:15:01
# 1  2025-08-13           1  Wednesday          Easy      3.45  00:30:12
# 2  2025-08-14           1   Thursday          Easy      2.17  00:21:13
# 3  2025-08-15           1     Friday          Easy      2.23  00:20:31
# 4  2025-08-17           1     Sunday      Long Run      6.60  00:59:17
# 5  2025-08-19           2    Tuesday      Easy Run      2.18  00:24:23
# 6  2025-08-20           2  Wednesday  Training Run      5.02  00:46:24
# 7  2025-08-22           2     Friday  Training Run      3.13  00:27:53
#
#   AveragePace  Calories                 Location  Weather  Effort  \
# 0        9:57       181   South Barrington, Road       80       3
# 1        8:44       547            Chicago, City       74       4
# 2        9:44       344            Chicago, City       73       2
# ...
